# %%
#import libraries 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import itertools
import datetime as dt
from scipy import stats
from IPython.display import display
import warnings
warnings.filterwarnings('ignore')
import os
import gc 
import pandas_profiling

# %%
test_bundas = pd.read_csv('C:/Users/jonathan/Desktop/ilabdata/bundas_test.csv')

# %%
# Checking Null values in test Set
test_bundas.isnull().sum()
# Out:
# Item_ID                        0
# Weight                       976
# FatContent                     0
# Visibility                     0
# Category                       0
# Max_Price                      0
# Store_ID                       0
# Store_Establishment_Year       0
# Store_Size                  1606
# Store_Location_Type            0
# Store_Type                     0
# dtype: int64

# %%
from sklearn.preprocessing import Imputer

# %%
# replace missing values with the column mean
df_mean_imputed = test_bundas.fillna(test_bundas.mean())
#df_median_imputed = train_bundas.fillna(train_bundas.median())
df_mean_imputed.head(15)
# Out:
#    Item_ID     Weight FatContent  Visibility               Category  \
# 0    FDW58  20.750000    Low Fat    0.007565            Snack Foods
# 1    FDW14   8.300000        reg    0.038428                  Dairy
# 2    NCN55  14.600000    Low Fat    0.099575                 Others
# 3    FDQ58   7.315000    Low Fat    0.015388            Snack Foods
# 4    FDY38  12.695633    Regular    0.118599                  Dairy
# 5    FDH56   9.800000    Regular    0.063817  Fruits and Vegetables
# 6    FDL48  19.350000    Regular    0.082602           Baking Goods
# 7    FDC48  12.695633    Low Fat    0.015782           Baking Goods
# 8    FDN33   6.305000    Regular    0.123365            Snack Foods
# 9    FDA36   5.985000    Low Fat    0.005698           Baking Goods
# 10   FDT44  16.600000    Low Fat    0.103569  Fruits and Vegetables
# 11   FDQ56   6.590000    Low Fat    0.105811  Fruits and Vegetables
# 12   NCC54  12.695633    Low Fat    0.171079     Health and Hygiene
# 13   FDU11   4.785000    Low Fat    0.092738                 Breads
# 14   DRL59  16.750000         LF    0.021206            Hard Drinks
#
#     Max_Price Store_ID  Store_Establishment_Year Store_Size  \
# 0    107.8622   OUT049                      1999     Medium
# 1     87.3198   OUT017                      2007        NaN
# 2    241.7538   OUT010                      1998        NaN
# 3    155.0340   OUT017                      2007        NaN
# 4    234.2300   OUT027                      1985     Medium
# 5    117.1492   OUT046                      1997      Small
# 6     50.1034   OUT018                      2009     Medium
# 7     81.0592   OUT027                      1985     Medium
# 8     95.7436   OUT045                      2002        NaN
# 9    186.8924   OUT017                      2007        NaN
# 10   118.3466   OUT017                      2007        NaN
# 11    85.3908   OUT045                      2002        NaN
# 12   240.4196   OUT019                      1985      Small
# 13   122.3098   OUT049                      1999     Medium
# 14    52.0298   OUT013                      1987       High
#
#    Store_Location_Type         Store_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store
# 3               Tier 2  Supermarket Type1
# 4               Tier 3  Supermarket Type3
# 5               Tier 1  Supermarket Type1
# 6               Tier 3  Supermarket Type2
# 7               Tier 3  Supermarket Type3
# 8               Tier 2  Supermarket Type1
# 9               Tier 2  Supermarket Type1
# 10              Tier 2  Supermarket Type1
# 11              Tier 2  Supermarket Type1
# 12              Tier 1      Grocery Store
# 13              Tier 1  Supermarket Type1
# 14              Tier 3  Supermarket Type1

# %%
# Checking Null values in test Set
df_mean_imputed.isnull().sum()
# Out:
# Item_ID                        0
# Weight                         0
# FatContent                     0
# Visibility                     0
# Category                       0
# Max_Price                      0
# Store_ID                       0
# Store_Establishment_Year       0
# Store_Size                  1606
# Store_Location_Type            0
# Store_Type                     0
# dtype: int64

# %%
modDf = df_mean_imputed.dropna(how='any', subset=['Store_Size'])

# %%
# One hot encode the categorical columns
FatContent_one_hot = pd.get_dummies(modDf['FatContent'], 
                                     prefix='FatContent')

Category_one_hot = pd.get_dummies(modDf['Category'], 
                                prefix='Category')

Store_Size_one_hot = pd.get_dummies(modDf['Store_Size'], 
                                   prefix='Store_Size')

# One hot encode the categorical columns
Store_Location_Type_one_hot = pd.get_dummies(modDf['Store_Location_Type'], 
                                     prefix='Store_Location_Type')

Store_Type_one_hot = pd.get_dummies(modDf['Store_Type'], 
                                prefix='Store_Type')

Store_ID_one_hot = pd.get_dummies(modDf['Store_ID'], 
                                   prefix='Store_ID')

# %%
# Combine the one hot encoded columns with df_con_enc
modDfenc = pd.concat([modDf, 
                        FatContent_one_hot, 
                        Category_one_hot, 
                        Store_Size_one_hot,
                        Store_Location_Type_one_hot, 
                        Store_Type_one_hot, 
                        Store_ID_one_hot], axis=1)

# Drop the original categorical columns (because now they've been one hot encoded)
modDfenc = modDfenc.drop(['FatContent','Category','Store_Size','Store_Location_Type','Store_Type','Store_ID'], axis=1)

# %%
# Seclect the dataframe we want to use first for predictions
selected_df = modDfenc

# %%
selected_df.to_csv("C:/Users/jonathan/Desktop/ilabdata/test_modified.csv",index=False)
